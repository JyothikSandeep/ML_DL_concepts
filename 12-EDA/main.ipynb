# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

data=pd.read_csv("./Algerian_forest_fires_dataset_UPDATE.csv",header=1)

data
# Out:
#     day month  year Temperature  RH  Ws Rain   FFMC  DMC    DC  ISI   BUI  \
# 0    01    06  2012          29  57  18     0  65.7  3.4   7.6  1.3   3.4
# 1    02    06  2012          29  61  13   1.3  64.4  4.1   7.6    1   3.9
# 2    03    06  2012          26  82  22  13.1  47.1  2.5   7.1  0.3   2.7
# 3    04    06  2012          25  89  13   2.5  28.6  1.3   6.9    0   1.7
# 4    05    06  2012          27  77  16     0  64.8    3  14.2  1.2   3.9
# ..   ..   ...   ...         ...  ..  ..   ...   ...  ...   ...  ...   ...
# 241  26    09  2012          30  65  14     0  85.4   16  44.5  4.5  16.9
# 242  27    09  2012          28  87  15   4.4  41.1  6.5     8  0.1   6.2
# 243  28    09  2012          27  87  29   0.5  45.9  3.5   7.9  0.4   3.4
# 244  29    09  2012          24  54  18   0.1  79.7  4.3  15.2  1.7   5.1
# 245  30    09  2012          24  64  15   0.2  67.3  3.8  16.5  1.2   4.8
#
#      FWI     Classes
# 0    0.5   not fire
# 1    0.4   not fire
# 2    0.1   not fire
# 3      0   not fire
# 4    0.5   not fire
# ..   ...           ...
# 241  6.5       fire
# 242    0   not fire
# 243  0.2   not fire
# 244  0.7   not fire
# 245  0.5  not fire
#
# [246 rows x 14 columns]

# %%
data.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 246 entries, 0 to 245
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   day          246 non-null    str
#  1   month        245 non-null    str
#  2   year         245 non-null    str
#  3   Temperature  245 non-null    str
#  4    RH          245 non-null    str
#  5    Ws          245 non-null    str
#  6   Rain         245 non-null    str
#  7   FFMC         245 non-null    str
#  8   DMC          245 non-null    str
#  9   DC           245 non-null    str
#  10  ISI          245 non-null    str
#  11  BUI          245 non-null    str
#  12  FWI          245 non-null    str
#  13  Classes      244 non-null    str
# dtypes: str(14)
# memory usage: 38.2 KB

# %%
# data cleaning

data[data.isnull().any(axis=1)]
# Out:
#                                day month  year Temperature   RH   Ws Rain   \
# 122  Sidi-Bel Abbes Region Dataset   NaN   NaN         NaN  NaN  NaN   NaN
# 167                             14    07  2012          37   37   18   0.2
#
#      FFMC   DMC      DC   ISI   BUI      FWI Classes
# 122   NaN   NaN     NaN   NaN   NaN      NaN       NaN
# 167  88.9  12.9  14.6 9  12.5  10.4  fire          NaN

# %%
data.loc[:122,"Region"]=0

data.loc[122:,"Region"]=1

# %%
data[:122]
# Out:
#     day month  year Temperature  RH  Ws Rain   FFMC  DMC    DC  ISI  BUI  FWI  \
# 0    01    06  2012          29  57  18     0  65.7  3.4   7.6  1.3  3.4  0.5
# 1    02    06  2012          29  61  13   1.3  64.4  4.1   7.6    1  3.9  0.4
# 2    03    06  2012          26  82  22  13.1  47.1  2.5   7.1  0.3  2.7  0.1
# 3    04    06  2012          25  89  13   2.5  28.6  1.3   6.9    0  1.7    0
# 4    05    06  2012          27  77  16     0  64.8    3  14.2  1.2  3.9  0.5
# ..   ..   ...   ...         ...  ..  ..   ...   ...  ...   ...  ...  ...  ...
# 117  26    09  2012          31  54  11     0    82    6  16.3  2.5  6.2  1.7
# 118  27    09  2012          31  66  11     0  85.7  8.3  24.9    4    9  4.1
# 119  28    09  2012          32  47  14   0.7  77.5  7.1   8.8  1.8  6.8  0.9
# 120  29    09  2012          26  80  16   1.8  47.4  2.9   7.7  0.3    3  0.1
# 121  30    09  2012          25  78  14   1.4    45  1.9   7.5  0.2  2.4  0.1
#
#        Classes    Region
# 0    not fire        0.0
# 1    not fire        0.0
# 2    not fire        0.0
# 3    not fire        0.0
# 4    not fire        0.0
# ..           ...     ...
# 117  not fire        0.0
# 118      fire        0.0
# 119  not fire        0.0
# 120  not fire        0.0
# 121  not fire        0.0
#
# [122 rows x 15 columns]

# %%
data[122:].head()
# Out:
#                                day  month  year  Temperature   RH   Ws  Rain   \
# 122  Sidi-Bel Abbes Region Dataset    NaN   NaN          NaN  NaN  NaN    NaN
# 123                            day  month  year  Temperature   RH   Ws  Rain
# 124                             01     06  2012           32   71   12    0.7
# 125                             02     06  2012           30   73   13      4
# 126                             03     06  2012           29   80   14      2
#
#      FFMC  DMC   DC  ISI  BUI  FWI    Classes    Region
# 122   NaN  NaN  NaN  NaN  NaN  NaN          NaN     1.0
# 123  FFMC  DMC   DC  ISI  BUI  FWI    Classes       1.0
# 124  57.1  2.5  8.2  0.6  2.8  0.2  not fire        1.0
# 125  55.7  2.7  7.8  0.6  2.9  0.2  not fire        1.0
# 126  48.7  2.2  7.6  0.3  2.6  0.1  not fire        1.0

# %%
data.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 246 entries, 0 to 245
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   day          246 non-null    str
#  1   month        245 non-null    str
#  2   year         245 non-null    str
#  3   Temperature  245 non-null    str
#  4    RH          245 non-null    str
#  5    Ws          245 non-null    str
#  6   Rain         245 non-null    str
#  7   FFMC         245 non-null    str
#  8   DMC          245 non-null    str
#  9   DC           245 non-null    str
#  10  ISI          245 non-null    str
#  11  BUI          245 non-null    str
#  12  FWI          245 non-null    str
#  13  Classes      244 non-null    str
#  14  Region       246 non-null    float64
# dtypes: float64(1), str(14)
# memory usage: 40.1 KB

# %%
data[["Region"]]=data[["Region"]].astype(int)

# %%
data.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 246 entries, 0 to 245
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   day          246 non-null    str
#  1   month        245 non-null    str
#  2   year         245 non-null    str
#  3   Temperature  245 non-null    str
#  4    RH          245 non-null    str
#  5    Ws          245 non-null    str
#  6   Rain         245 non-null    str
#  7   FFMC         245 non-null    str
#  8   DMC          245 non-null    str
#  9   DC           245 non-null    str
#  10  ISI          245 non-null    str
#  11  BUI          245 non-null    str
#  12  FWI          245 non-null    str
#  13  Classes      244 non-null    str
#  14  Region       246 non-null    int64
# dtypes: int64(1), str(14)
# memory usage: 40.1 KB

# %%
data=data.dropna().reset_index(drop=True)

# %%
data[122:]
# Out:
#      day  month  year  Temperature   RH   Ws  Rain   FFMC  DMC    DC  ISI  \
# 122  day  month  year  Temperature   RH   Ws  Rain   FFMC  DMC    DC  ISI
# 123   01     06  2012           32   71   12    0.7  57.1  2.5   8.2  0.6
# 124   02     06  2012           30   73   13      4  55.7  2.7   7.8  0.6
# 125   03     06  2012           29   80   14      2  48.7  2.2   7.6  0.3
# 126   04     06  2012           30   64   14      0  79.4  5.2  15.4  2.2
# ..   ...    ...   ...          ...  ...  ...    ...   ...  ...   ...  ...
# 239   26     09  2012           30   65   14      0  85.4   16  44.5  4.5
# 240   27     09  2012           28   87   15    4.4  41.1  6.5     8  0.1
# 241   28     09  2012           27   87   29    0.5  45.9  3.5   7.9  0.4
# 242   29     09  2012           24   54   18    0.1  79.7  4.3  15.2  1.7
# 243   30     09  2012           24   64   15    0.2  67.3  3.8  16.5  1.2
#
#       BUI  FWI     Classes    Region
# 122   BUI  FWI     Classes         1
# 123   2.8  0.2   not fire          1
# 124   2.9  0.2   not fire          1
# 125   2.6  0.1   not fire          1
# 126   5.6    1   not fire          1
# ..    ...  ...           ...     ...
# 239  16.9  6.5       fire          1
# 240   6.2    0   not fire          1
# 241   3.4  0.2   not fire          1
# 242   5.1  0.7   not fire          1
# 243   4.8  0.5  not fire           1
#
# [122 rows x 15 columns]

# %%
data=data.drop(122).reset_index(drop=True)

# %%
data.columns
# Out:
# Index(['day', 'month', 'year', 'Temperature', ' RH', ' Ws', 'Rain ', 'FFMC',
#        'DMC', 'DC', 'ISI', 'BUI', 'FWI', 'Classes  ', 'Region'],
#       dtype='str')

# %%
# fixing space in cloumns

data.columns=data.columns.str.strip()

data.columns
# Out:
# Index(['day', 'month', 'year', 'Temperature', 'RH', 'Ws', 'Rain', 'FFMC',
#        'DMC', 'DC', 'ISI', 'BUI', 'FWI', 'Classes', 'Region'],
#       dtype='str')

# %%
data.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 243 entries, 0 to 242
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   day          243 non-null    str
#  1   month        243 non-null    str
#  2   year         243 non-null    str
#  3   Temperature  243 non-null    str
#  4   RH           243 non-null    str
#  5   Ws           243 non-null    str
#  6   Rain         243 non-null    str
#  7   FFMC         243 non-null    str
#  8   DMC          243 non-null    str
#  9   DC           243 non-null    str
#  10  ISI          243 non-null    str
#  11  BUI          243 non-null    str
#  12  FWI          243 non-null    str
#  13  Classes      243 non-null    str
#  14  Region       243 non-null    int64
# dtypes: int64(1), str(14)
# memory usage: 39.6 KB

# %%
data.head()
# Out:
#   day month  year Temperature  RH  Ws  Rain  FFMC  DMC    DC  ISI  BUI  FWI  \
# 0  01    06  2012          29  57  18     0  65.7  3.4   7.6  1.3  3.4  0.5
# 1  02    06  2012          29  61  13   1.3  64.4  4.1   7.6    1  3.9  0.4
# 2  03    06  2012          26  82  22  13.1  47.1  2.5   7.1  0.3  2.7  0.1
# 3  04    06  2012          25  89  13   2.5  28.6  1.3   6.9    0  1.7    0
# 4  05    06  2012          27  77  16     0  64.8    3  14.2  1.2  3.9  0.5
#
#        Classes  Region
# 0  not fire          0
# 1  not fire          0
# 2  not fire          0
# 3  not fire          0
# 4  not fire          0

# %%
# changing the requried data types

data[["day","month","year","Temperature","RH","Ws"]]=data[["day","month","year","Temperature","RH","Ws"]].astype(int)

# %%
data.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 243 entries, 0 to 242
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   day          243 non-null    int64
#  1   month        243 non-null    int64
#  2   year         243 non-null    int64
#  3   Temperature  243 non-null    int64
#  4   RH           243 non-null    int64
#  5   Ws           243 non-null    int64
#  6   Rain         243 non-null    str
#  7   FFMC         243 non-null    str
#  8   DMC          243 non-null    str
#  9   DC           243 non-null    str
#  10  ISI          243 non-null    str
#  11  BUI          243 non-null    str
#  12  FWI          243 non-null    str
#  13  Classes      243 non-null    str
#  14  Region       243 non-null    int64
# dtypes: int64(7), str(8)
# memory usage: 36.1 KB

# %%
strings=[f  for f in data.columns if data[f].dtypes=="str"]

# %%
for i in strings:
    if(i!="Classes"):
        data[[i]]=data[[i]].astype(float)

# %%
data.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 243 entries, 0 to 242
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   day          243 non-null    int64
#  1   month        243 non-null    int64
#  2   year         243 non-null    int64
#  3   Temperature  243 non-null    int64
#  4   RH           243 non-null    int64
#  5   Ws           243 non-null    int64
#  6   Rain         243 non-null    float64
#  7   FFMC         243 non-null    float64
#  8   DMC          243 non-null    float64
#  9   DC           243 non-null    float64
#  10  ISI          243 non-null    float64
#  11  BUI          243 non-null    float64
#  12  FWI          243 non-null    float64
#  13  Classes      243 non-null    str
#  14  Region       243 non-null    int64
# dtypes: float64(7), int64(7), str(1)
# memory usage: 30.7 KB

# %%
data.describe()
# Out:
#               day       month    year  Temperature          RH          Ws  \
# count  243.000000  243.000000   243.0   243.000000  243.000000  243.000000
# mean    15.761317    7.502058  2012.0    32.152263   62.041152   15.493827
# std      8.842552    1.114793     0.0     3.628039   14.828160    2.811385
# min      1.000000    6.000000  2012.0    22.000000   21.000000    6.000000
# 25%      8.000000    7.000000  2012.0    30.000000   52.500000   14.000000
# 50%     16.000000    8.000000  2012.0    32.000000   63.000000   15.000000
# 75%     23.000000    8.000000  2012.0    35.000000   73.500000   17.000000
# max     31.000000    9.000000  2012.0    42.000000   90.000000   29.000000
#
#              Rain        FFMC         DMC          DC         ISI         BUI  \
# count  243.000000  243.000000  243.000000  243.000000  243.000000  243.000000
# mean     0.762963   77.842387   14.680658   49.430864    4.742387   16.690535
# std      2.003207   14.349641   12.393040   47.665606    4.154234   14.228421
# min      0.000000   28.600000    0.700000    6.900000    0.000000    1.100000
# 25%      0.000000   71.850000    5.800000   12.350000    1.400000    6.000000
# 50%      0.000000   83.300000   11.300000   33.100000    3.500000   12.400000
# 75%      0.500000   88.300000   20.800000   69.100000    7.250000   22.650000
# max     16.800000   96.000000   65.900000  220.400000   19.000000   68.000000
#
#               FWI      Region
# count  243.000000  243.000000
# mean     7.035391    0.497942
# std      7.440568    0.501028
# min      0.000000    0.000000
# 25%      0.700000    0.000000
# 50%      4.200000    0.000000
# 75%     11.450000    1.000000
# max     31.100000    1.000000

# %%
data
# Out:
#      day  month  year  Temperature  RH  Ws  Rain  FFMC   DMC    DC  ISI   BUI  \
# 0      1      6  2012           29  57  18   0.0  65.7   3.4   7.6  1.3   3.4
# 1      2      6  2012           29  61  13   1.3  64.4   4.1   7.6  1.0   3.9
# 2      3      6  2012           26  82  22  13.1  47.1   2.5   7.1  0.3   2.7
# 3      4      6  2012           25  89  13   2.5  28.6   1.3   6.9  0.0   1.7
# 4      5      6  2012           27  77  16   0.0  64.8   3.0  14.2  1.2   3.9
# ..   ...    ...   ...          ...  ..  ..   ...   ...   ...   ...  ...   ...
# 238   26      9  2012           30  65  14   0.0  85.4  16.0  44.5  4.5  16.9
# 239   27      9  2012           28  87  15   4.4  41.1   6.5   8.0  0.1   6.2
# 240   28      9  2012           27  87  29   0.5  45.9   3.5   7.9  0.4   3.4
# 241   29      9  2012           24  54  18   0.1  79.7   4.3  15.2  1.7   5.1
# 242   30      9  2012           24  64  15   0.2  67.3   3.8  16.5  1.2   4.8
#
#      FWI       Classes  Region
# 0    0.5   not fire          0
# 1    0.4   not fire          0
# 2    0.1   not fire          0
# 3    0.0   not fire          0
# 4    0.5   not fire          0
# ..   ...           ...     ...
# 238  6.5       fire          1
# 239  0.0   not fire          1
# 240  0.2   not fire          1
# 241  0.7   not fire          1
# 242  0.5  not fire           1
#
# [243 rows x 15 columns]

# %%
data.to_csv("cleaned_dataset.csv",index=False)

# %%
data=pd.read_csv('./cleaned_dataset.csv')

# %%
data=data.drop(columns=["day","month","year"])

# %%
data.head()
# Out:
#    Temperature  RH  Ws  Rain  FFMC  DMC    DC  ISI  BUI  FWI      Classes  \
# 0           29  57  18   0.0  65.7  3.4   7.6  1.3  3.4  0.5  not fire
# 1           29  61  13   1.3  64.4  4.1   7.6  1.0  3.9  0.4  not fire
# 2           26  82  22  13.1  47.1  2.5   7.1  0.3  2.7  0.1  not fire
# 3           25  89  13   2.5  28.6  1.3   6.9  0.0  1.7  0.0  not fire
# 4           27  77  16   0.0  64.8  3.0  14.2  1.2  3.9  0.5  not fire
#
#    Region
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0

# %%
# encoding

# data["Classes"]=np.where(data["Classes"]=="not fire",0,1)

# %%
# data.head()

# %%
data["Classes"].value_counts()
# Out:
# Classes
# fire             131
# not fire         101
# fire               4
# fire               2
# not fire           2
# not fire           1
# not fire           1
# not fire           1
# Name: count, dtype: int64

# %%
# here we have different classes

data["Classes"]=np.where(data["Classes"].str.contains('not fire'),0,1)

# %%
data.head()
# Out:
#    Temperature  RH  Ws  Rain  FFMC  DMC    DC  ISI  BUI  FWI  Classes  Region
# 0           29  57  18   0.0  65.7  3.4   7.6  1.3  3.4  0.5        0       0
# 1           29  61  13   1.3  64.4  4.1   7.6  1.0  3.9  0.4        0       0
# 2           26  82  22  13.1  47.1  2.5   7.1  0.3  2.7  0.1        0       0
# 3           25  89  13   2.5  28.6  1.3   6.9  0.0  1.7  0.0        0       0
# 4           27  77  16   0.0  64.8  3.0  14.2  1.2  3.9  0.5        0       0

# %%
data["Classes"].value_counts()
# Out:
# Classes
# 1    137
# 0    106
# Name: count, dtype: int64

# %%
# desity for all plot features

data.hist(bins=50,figsize=(20,15))

plt.show()

# %%
# corelation:


data.corr()
# Out:
#              Temperature        RH        Ws      Rain      FFMC       DMC  \
# Temperature     1.000000 -0.651400 -0.284510 -0.326492  0.676568  0.485687
# RH             -0.651400  1.000000  0.244048  0.222356 -0.644873 -0.408519
# Ws             -0.284510  0.244048  1.000000  0.171506 -0.166548 -0.000721
# Rain           -0.326492  0.222356  0.171506  1.000000 -0.543906 -0.288773
# FFMC            0.676568 -0.644873 -0.166548 -0.543906  1.000000  0.603608
# DMC             0.485687 -0.408519 -0.000721 -0.288773  0.603608  1.000000
# DC              0.376284 -0.226941  0.079135 -0.298023  0.507397  0.875925
# ISI             0.603871 -0.686667  0.008532 -0.347484  0.740007  0.680454
# BUI             0.459789 -0.353841  0.031438 -0.299852  0.592011  0.982248
# FWI             0.566670 -0.580957  0.032368 -0.324422  0.691132  0.875864
# Classes         0.516015 -0.432161 -0.069964 -0.379097  0.769492  0.585658
# Region          0.269555 -0.402682 -0.181160 -0.040013  0.222241  0.192089
#
#                    DC       ISI       BUI       FWI   Classes    Region
# Temperature  0.376284  0.603871  0.459789  0.566670  0.516015  0.269555
# RH          -0.226941 -0.686667 -0.353841 -0.580957 -0.432161 -0.402682
# Ws           0.079135  0.008532  0.031438  0.032368 -0.069964 -0.181160
# Rain        -0.298023 -0.347484 -0.299852 -0.324422 -0.379097 -0.040013
# FFMC         0.507397  0.740007  0.592011  0.691132  0.769492  0.222241
# DMC          0.875925  0.680454  0.982248  0.875864  0.585658  0.192089
# DC           1.000000  0.508643  0.941988  0.739521  0.511123 -0.078734
# ISI          0.508643  1.000000  0.644093  0.922895  0.735197  0.263197
# BUI          0.941988  0.644093  1.000000  0.857973  0.586639  0.089408
# FWI          0.739521  0.922895  0.857973  1.000000  0.719216  0.197102
# Classes      0.511123  0.735197  0.586639  0.719216  1.000000  0.162347
# Region      -0.078734  0.263197  0.089408  0.197102  0.162347  1.000000

# %%
sns.heatmap(data.corr())
# Out:
# <Axes: >

# %%
df=pd.read_csv("cleaned_dataset.csv")


df.head()
# Out:
#    day  month  year  Temperature  RH  Ws  Rain  FFMC  DMC    DC  ISI  BUI  \
# 0    1      6  2012           29  57  18   0.0  65.7  3.4   7.6  1.3  3.4
# 1    2      6  2012           29  61  13   1.3  64.4  4.1   7.6  1.0  3.9
# 2    3      6  2012           26  82  22  13.1  47.1  2.5   7.1  0.3  2.7
# 3    4      6  2012           25  89  13   2.5  28.6  1.3   6.9  0.0  1.7
# 4    5      6  2012           27  77  16   0.0  64.8  3.0  14.2  1.2  3.9
#
#    FWI      Classes  Region
# 0  0.5  not fire          0
# 1  0.4  not fire          0
# 2  0.1  not fire          0
# 3  0.0  not fire          0
# 4  0.5  not fire          0

# %%
df.columns
# Out:
# Index(['day', 'month', 'year', 'Temperature', 'RH', 'Ws', 'Rain', 'FFMC',
#        'DMC', 'DC', 'ISI', 'BUI', 'FWI', 'Classes', 'Region'],
#       dtype='str')

# %%
    # drop month data and year

df.drop(["day","month","year"],axis=1,inplace=True)

df
# Out:
#      Temperature  RH  Ws  Rain  FFMC   DMC    DC  ISI   BUI  FWI  \
# 0             29  57  18   0.0  65.7   3.4   7.6  1.3   3.4  0.5
# 1             29  61  13   1.3  64.4   4.1   7.6  1.0   3.9  0.4
# 2             26  82  22  13.1  47.1   2.5   7.1  0.3   2.7  0.1
# 3             25  89  13   2.5  28.6   1.3   6.9  0.0   1.7  0.0
# 4             27  77  16   0.0  64.8   3.0  14.2  1.2   3.9  0.5
# ..           ...  ..  ..   ...   ...   ...   ...  ...   ...  ...
# 238           30  65  14   0.0  85.4  16.0  44.5  4.5  16.9  6.5
# 239           28  87  15   4.4  41.1   6.5   8.0  0.1   6.2  0.0
# 240           27  87  29   0.5  45.9   3.5   7.9  0.4   3.4  0.2
# 241           24  54  18   0.1  79.7   4.3  15.2  1.7   5.1  0.7
# 242           24  64  15   0.2  67.3   3.8  16.5  1.2   4.8  0.5
#
#           Classes  Region
# 0     not fire          0
# 1     not fire          0
# 2     not fire          0
# 3     not fire          0
# 4     not fire          0
# ..            ...     ...
# 238       fire          1
# 239   not fire          1
# 240   not fire          1
# 241   not fire          1
# 242  not fire           1
#
# [243 rows x 12 columns]

# %%
df["Classes"].value_counts()
# Out:
# Classes
# fire             131
# not fire         101
# fire               4
# fire               2
# not fire           2
# not fire           1
# not fire           1
# not fire           1
# Name: count, dtype: int64

# %%
df["Classes"]=np.where(df["Classes"].str.contains("not fire"),0,1)

# %%
df.head()
# Out:
#    Temperature  RH  Ws  Rain  FFMC  DMC    DC  ISI  BUI  FWI  Classes  Region
# 0           29  57  18   0.0  65.7  3.4   7.6  1.3  3.4  0.5        0       0
# 1           29  61  13   1.3  64.4  4.1   7.6  1.0  3.9  0.4        0       0
# 2           26  82  22  13.1  47.1  2.5   7.1  0.3  2.7  0.1        0       0
# 3           25  89  13   2.5  28.6  1.3   6.9  0.0  1.7  0.0        0       0
# 4           27  77  16   0.0  64.8  3.0  14.2  1.2  3.9  0.5        0       0

# %%
df["Classes"].value_counts()
# Out:
# Classes
# 1    137
# 0    106
# Name: count, dtype: int64

# %%
df.corr()
# Out:
#              Temperature        RH        Ws      Rain      FFMC       DMC  \
# Temperature     1.000000 -0.651400 -0.284510 -0.326492  0.676568  0.485687
# RH             -0.651400  1.000000  0.244048  0.222356 -0.644873 -0.408519
# Ws             -0.284510  0.244048  1.000000  0.171506 -0.166548 -0.000721
# Rain           -0.326492  0.222356  0.171506  1.000000 -0.543906 -0.288773
# FFMC            0.676568 -0.644873 -0.166548 -0.543906  1.000000  0.603608
# DMC             0.485687 -0.408519 -0.000721 -0.288773  0.603608  1.000000
# DC              0.376284 -0.226941  0.079135 -0.298023  0.507397  0.875925
# ISI             0.603871 -0.686667  0.008532 -0.347484  0.740007  0.680454
# BUI             0.459789 -0.353841  0.031438 -0.299852  0.592011  0.982248
# FWI             0.566670 -0.580957  0.032368 -0.324422  0.691132  0.875864
# Classes         0.516015 -0.432161 -0.069964 -0.379097  0.769492  0.585658
# Region          0.269555 -0.402682 -0.181160 -0.040013  0.222241  0.192089
#
#                    DC       ISI       BUI       FWI   Classes    Region
# Temperature  0.376284  0.603871  0.459789  0.566670  0.516015  0.269555
# RH          -0.226941 -0.686667 -0.353841 -0.580957 -0.432161 -0.402682
# Ws           0.079135  0.008532  0.031438  0.032368 -0.069964 -0.181160
# Rain        -0.298023 -0.347484 -0.299852 -0.324422 -0.379097 -0.040013
# FFMC         0.507397  0.740007  0.592011  0.691132  0.769492  0.222241
# DMC          0.875925  0.680454  0.982248  0.875864  0.585658  0.192089
# DC           1.000000  0.508643  0.941988  0.739521  0.511123 -0.078734
# ISI          0.508643  1.000000  0.644093  0.922895  0.735197  0.263197
# BUI          0.941988  0.644093  1.000000  0.857973  0.586639  0.089408
# FWI          0.739521  0.922895  0.857973  1.000000  0.719216  0.197102
# Classes      0.511123  0.735197  0.586639  0.719216  1.000000  0.162347
# Region      -0.078734  0.263197  0.089408  0.197102  0.162347  1.000000

# %%
sns.heatmap(df.corr())
# Out:
# <Axes: >

# %%
# independent and dependent features

X=df.drop("FWI",axis=1)
y=df["FWI"]

X,y
# Out:
# (     Temperature  RH  Ws  Rain  FFMC   DMC    DC  ISI   BUI  Classes  Region
#  0             29  57  18   0.0  65.7   3.4   7.6  1.3   3.4        0       0
#  1             29  61  13   1.3  64.4   4.1   7.6  1.0   3.9        0       0
#  2             26  82  22  13.1  47.1   2.5   7.1  0.3   2.7        0       0
#  3             25  89  13   2.5  28.6   1.3   6.9  0.0   1.7        0       0
#  4             27  77  16   0.0  64.8   3.0  14.2  1.2   3.9        0       0
#  ..           ...  ..  ..   ...   ...   ...   ...  ...   ...      ...     ...
#  238           30  65  14   0.0  85.4  16.0  44.5  4.5  16.9        1       1
#  239           28  87  15   4.4  41.1   6.5   8.0  0.1   6.2        0       1
#  240           27  87  29   0.5  45.9   3.5   7.9  0.4   3.4        0       1
#  241           24  54  18   0.1  79.7   4.3  15.2  1.7   5.1        0       1
#  242           24  64  15   0.2  67.3   3.8  16.5  1.2   4.8        0       1
#
#  [243 rows x 11 columns],
#  0      0.5
#  1      0.4
#  2      0.1
#  3      0.0
#  4      0.5
#        ...
#  238    6.5
#  239    0.0
#  240    0.2
#  241    0.7
#  242    0.5
#  Name: FWI, Length: 243, dtype: float64)

# %%
# Train test split

from sklearn.model_selection import train_test_split

X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.25,random_state=41)

# %%
X_train.shape,X_test.shape
# Out:
# ((182, 11), (61, 11))

# %%
X_train
# Out:
#      Temperature  RH  Ws  Rain  FFMC   DMC     DC   ISI   BUI  Classes  Region
# 41            31  75  13   0.1  75.1   7.9   27.7   1.5   9.2        0       0
# 112           31  55  11   0.0  87.8  16.5   57.9   5.4  19.2        1       0
# 133           27  58  17   0.0  88.9  21.3   37.8   8.7  21.2        1       1
# 91            28  80  21  16.8  52.5   8.7    8.7   0.6   8.3        0       0
# 37            33  68  19   0.0  85.6  12.5   49.8   6.0  15.4        1       0
# ..           ...  ..  ..   ...   ...   ...    ...   ...   ...      ...     ...
# 80            35  68  19   0.0  88.3  25.9  130.6   8.8  34.7        1       0
# 226           28  81  15   0.0  84.6  12.6   41.5   4.3  14.3        1       1
# 140           32  67  14   4.5  64.6   4.4    8.2   1.0   4.2        0       1
# 163           36  44  13   0.0  90.1  12.6   19.4   8.3  12.5        1       1
# 192           40  31  15   0.0  94.2  22.5   46.3  16.6  22.4        1       1
#
# [182 rows x 11 columns]

# %%
y_train.shape,y_test.shape
# Out:
# ((182,), (61,))

# %%
X_train.corr()
# Out:
#              Temperature        RH        Ws      Rain      FFMC       DMC  \
# Temperature     1.000000 -0.632603 -0.276940 -0.330300  0.696636  0.485381
# RH             -0.632603  1.000000  0.284878  0.216989 -0.648727 -0.430816
# Ws             -0.276940  0.284878  1.000000  0.187858 -0.202555 -0.023306
# Rain           -0.330300  0.216989  0.187858  1.000000 -0.528326 -0.279693
# FFMC            0.696636 -0.648727 -0.202555 -0.528326  1.000000  0.616007
# DMC             0.485381 -0.430816 -0.023306 -0.279693  0.616007  1.000000
# DC              0.402618 -0.268378  0.058029 -0.289968  0.522644  0.878280
# ISI             0.612643 -0.674245 -0.028594 -0.338240  0.749150  0.691288
# BUI             0.469295 -0.385272  0.009506 -0.290936  0.607508  0.982519
# Classes         0.544552 -0.429688 -0.128823 -0.360923  0.777949  0.606479
# Region          0.217014 -0.382272 -0.205389 -0.050380  0.213566  0.194447
#
#                    DC       ISI       BUI   Classes    Region
# Temperature  0.402618  0.612643  0.469295  0.544552  0.217014
# RH          -0.268378 -0.674245 -0.385272 -0.429688 -0.382272
# Ws           0.058029 -0.028594  0.009506 -0.128823 -0.205389
# Rain        -0.289968 -0.338240 -0.290936 -0.360923 -0.050380
# FFMC         0.522644  0.749150  0.607508  0.777949  0.213566
# DMC          0.878280  0.691288  0.982519  0.606479  0.194447
# DC           1.000000  0.530794  0.941766  0.528517 -0.062961
# ISI          0.530794  1.000000  0.662441  0.751002  0.235096
# BUI          0.941766  0.662441  1.000000  0.610694  0.096437
# Classes      0.528517  0.751002  0.610694  1.000000  0.132260
# Region      -0.062961  0.235096  0.096437  0.132260  1.000000

# %%
plt.figure(figsize=(10,10))

corr=X_train.corr()
sns.heatmap(corr,annot=True)
# Out:
# <Axes: >

# %%
def correlation(dataset,threshold):

    corr=dataset.corr()
    # print(corr)
    corr_set=set()
    for i in range(len(corr.columns)):
        for j in range(i):
            if(corr.iloc[i,j]>threshold):
                colname=corr.columns[i]

                corr_set.add(colname)


    return corr_set


corr_features=correlation(X_train,0.85)

# %%
X_train.drop(corr_features,axis=1,inplace=True)
X_test.drop(corr_features,axis=1,inplace=True)

# %%
from sklearn.preprocessing import StandardScaler

scaler=StandardScaler()

X_train_scaled=scaler.fit_transform(X_train)
X_test_scaled=scaler.transform(X_test)

# %%
X_train_scaled
# Out:
# array([[-0.27688003,  0.85321886, -0.87860649, ..., -0.75597877,
#         -1.08012345, -1.        ],
#        [-0.27688003, -0.50298928, -1.57084191, ...,  0.16190308,
#          0.9258201 , -1.        ],
#        [-1.36644038, -0.29955806,  0.50586434, ...,  0.93857234,
#          0.9258201 ,  1.        ],
#        ...,
#        [-0.00448995,  0.3107356 , -0.53248878, ..., -0.87365593,
#         -1.08012345,  1.        ],
#        [ 1.0850704 , -1.24890376, -0.87860649, ...,  0.84443061,
#          0.9258201 ,  1.        ],
#        [ 2.17463074, -2.13043906, -0.18637107, ...,  2.79787148,
#          0.9258201 ,  1.        ]], shape=(182, 9))

# %%
# Box plots

plt.figure(figsize=(15,8))

plt.subplot(1,2,1)

sns.boxplot(X_train)

plt.title("Before training")


plt.subplot(1,2,2)

sns.boxplot(X_test_scaled)

plt.title("After training")
# Out:
# Text(0.5, 1.0, 'After training')

# %%
# Model training

# %%
from sklearn.linear_model import LinearRegression

from sklearn.metrics import mean_absolute_error, r2_score

linear_reg=LinearRegression()

linear_reg.fit(X_train_scaled,y_train)


y_pred=linear_reg.predict(X_test_scaled)


plt.scatter(y_test,y_pred)
mae=mean_absolute_error(y_test,y_pred)

score=r2_score(y_test,y_pred)

print(mae,score)
# Out:
# 0.5670984536749403 0.9826446263791835

# %%
from sklearn.linear_model import Lasso

from sklearn.metrics import mean_absolute_error, r2_score

linear_reg=Lasso()

linear_reg.fit(X_train_scaled,y_train)


y_pred=linear_reg.predict(X_test_scaled)


plt.scatter(y_test,y_pred)
mae=mean_absolute_error(y_test,y_pred)

score=r2_score(y_test,y_pred)

print(mae,score)
# Out:
# 1.0185004953444199 0.9588635787062445

# %%
# Ridge

from sklearn.linear_model import Ridge

from sklearn.metrics import mean_absolute_error, r2_score

ridge_reg=Ridge()

ridge_reg.fit(X_train_scaled,y_train)


y_pred=ridge_reg.predict(X_test_scaled)


plt.scatter(y_test,y_pred)
mae=mean_absolute_error(y_test,y_pred)

score=r2_score(y_test,y_pred)

print(mae,score)
# Out:
# 0.5827892685716034 0.982027823305431

# %%
# Elastic net

from sklearn.linear_model import ElasticNet

from sklearn.metrics import mean_absolute_error, r2_score

linear_reg=ElasticNet()

linear_reg.fit(X_train_scaled,y_train)


y_pred=linear_reg.predict(X_test_scaled)


plt.scatter(y_test,y_pred)
mae=mean_absolute_error(y_test,y_pred)

score=r2_score(y_test,y_pred)

print(mae,score)
# Out:
# 1.6607844178200581 0.8913710465793633

# %%
# Hyperparameter tuning
