# %%
pip install numpy
# Out:
# Requirement already satisfied: numpy in c:\users\sandeep\anaconda3\lib\site-packages (2.1.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np

# %%
arr=np.array([1,2,3,4,5])
print(arr)
# Out:
# [1 2 3 4 5]

# %%
arr=np.array([[1,2],[3,4]])
print(arr)
# Out:
# [[1 2]
#  [3 4]]

# %%
arr.shape
# Out:
# (2, 2)

# %%
a = np.array([1, 2, 3])
b = np.array([4, 5, 6])

print(a + b)
# Out:
# [5 7 9]

# %%
arr.ndim
# Out:
# 2

# %%
print(arr.size)
# Out:
# 4

# %%
arr = np.array([1, 2, 3], dtype=float)

print(arr)
# Out:
# [1. 2. 3.]

# %%
np.zeros((2,3),dtype=int)
# Out:
# array([[0, 0, 0],
#        [0, 0, 0]])

# %%
np.ones((3,2),dtype=int)
# Out:
# array([[1, 1],
#        [1, 1],
#        [1, 1]])

# %%
np.eye(3)
# Out:
# array([[1., 0., 0.],
#        [0., 1., 0.],
#        [0., 0., 1.]])

# %%
np.full((2, 2), 7)
# Out:
# array([[7, 7],
#        [7, 7]])

# %%
np.random.rand(3,3)
# Out:
# array([[0.67831048, 0.23807715, 0.95880398],
#        [0.18420992, 0.79128471, 0.32024575],
#        [0.48350781, 0.43915945, 0.53278396]])

# %%
np.random.randint(1,10,(2,3))
# Out:
# array([[5, 9, 1],
#        [9, 4, 2]], dtype=int32)

# %%
arr = np.array([10, 20, 30])
arr = np.array([10, 20, 30])

# %%
arr = np.array([1, 2, 3])

print(arr + 10)
# Out:
# [11 12 13]

# %%
# matrix multiplication
a = np.array([
    [1, 2],
    [3, 4]
])

b = np.array([
    [5, 6],
    [7, 8]
])

print(a @ b)
# Out:
# [[19 22]
#  [43 50]]

# %%
arr=np.random.randint(1,20,(3,3))
print(arr)
arr.T
# Out:
# [[12  7 12]
#  [ 6 14  5]
#  [17  4  4]]
# array([[12,  6, 17],
#        [ 7, 14,  4],
#        [12,  5,  4]], dtype=int32)

# %%
arr = np.array([1, 2, 3, 4, 5, 6])

print(arr.reshape(2, 3))
# Out:
# [[1 2 3]
#  [4 5 6]]

# %%
print(arr.flatten())
# Out:
# [1 2 3 4 5 6]

# %%
# axios=0 -> column wise

# Axis=1 -> row wise

arr1=np.array([[1,2,3,4],[5,6,7,8]])
# arr2=np.array([3,4,5,6])

print(arr1)
print(np.sum(arr1,axis=0))
print(np.sum(arr1,axis=1))
# Out:
# [[1 2 3 4]
#  [5 6 7 8]]
# [ 6  8 10 12]
# [10 26]

# %%
arr = np.array([1, 2, 3, 4, 5])

print(arr > 3)
# Out:
# [False False False  True  True]

# %%
print(arr[arr > 3])
# Out:
# [4 5]
